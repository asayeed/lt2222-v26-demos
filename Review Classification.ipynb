# %%
import pandas as pd

# %%
review_df = pd.read_csv("IMDb_Reviews.csv")

# %%
review_df
# Out:
#                                                   review  sentiment
# 0      My family and I normally do not watch local mo...          1
# 1      Believe it or not, this was at one time the wo...          0
# 2      After some internet surfing, I found the "Home...          0
# 3      One of the most unheralded great works of anim...          1
# 4      It was the Sixties, and anyone with long hair ...          0
# ...                                                  ...        ...
# 49995  the people who came up with this are SICK AND ...          0
# 49996  The script is so so laughable... this in turn,...          0
# 49997  "So there's this bride, you see, and she gets ...          0
# 49998  Your mind will not be satisfied by this nobud...          0
# 49999  The chaser's war on everything is a weekly sho...          1
#
# [50000 rows x 2 columns]

# %%
from nltk.tokenize.stanford import StanfordTokenizer

# %%
StanfordTokenizer("I am the egg man. We are the egg men. I am the walrus.")
# Out:
# /tmp/ipykernel_1193604/1633051764.py:1: DeprecationWarning:
# The StanfordTokenizer will be deprecated in version 3.2.5.
# Please use nltk.parse.corenlp.CoreNLPParser instead.'
#   StanfordTokenizer("I am the egg man. We are the egg men. I am the walrus.")
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 StanfordTokenizer("I am the egg man. We are the egg men. I am the walrus.")
#
# File /usr/local/lib/python3.12/site-packages/nltk/tokenize/stanford.py:56, in StanfordTokenizer.__init__(self, path_to_jar, encoding, options, verbose, java_options)
#      37 def __init__(
#      38     self,
#      39     path_to_jar=None,
#    (...)
#      44 ):
#      45     # Raise deprecation warning.
#      46     warnings.warn(
#      47         str(
#      48             "\nThe StanfordTokenizer will "
#    (...)
#      53         stacklevel=2,
#      54     )
# ---> 56     self._stanford_jar = find_jar(
#      57         self._JAR,
#      58         path_to_jar,
#      59         env_vars=("STANFORD_POSTAGGER",),
#      60         searchpath=(),
#      61         url=_stanford_url,
#      62         verbose=verbose,
#      63     )
#      65     self._encoding = encoding
#      66     self.java_options = java_options
#
# File /usr/local/lib/python3.12/site-packages/nltk/internals.py:835, in find_jar(name_pattern, path_to_jar, env_vars, searchpath, url, verbose, is_regex)
#     826 def find_jar(
#     827     name_pattern,
#     828     path_to_jar=None,
#    (...)
#     833     is_regex=False,
#     834 ):
# --> 835     return next(
#     836         find_jar_iter(
#     837             name_pattern, path_to_jar, env_vars, searchpath, url, verbose, is_regex
#     838         )
#     839     )
#
# File /usr/local/lib/python3.12/site-packages/nltk/internals.py:721, in find_jar_iter(name_pattern, path_to_jar, env_vars, searchpath, url, verbose, is_regex)
#     719         yield path_to_jar
#     720     else:
# --> 721         raise LookupError(
#     722             f"Could not find {name_pattern} jar file at {path_to_jar}"
#     723         )
#     725 # Check environment variables
#     726 for env_var in env_vars:
#
# LookupError: Could not find stanford-postagger.jar jar file at I am the egg man. We are the egg men. I am the walrus.

# %%
from nltk.parse.corenlp import CoreNLPParser

# %%
CoreNLPParser("test")

# %%
import spacy

# %%
from spacy import Tokenizer
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 from spacy import Tokenizer
#
# ImportError: cannot import name 'Tokenizer' from 'spacy' (/usr/local/lib64/python3.12/site-packages/spacy/__init__.py)
