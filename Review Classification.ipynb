# %%
import pandas as pd

# %%
review_df = pd.read_csv("IMDb_Reviews.csv")

# %%
review_df

# %%
import spacy

# %%
from gensim.models.doc2vec import Doc2Vec, TaggedDocument

# %%
nlp = spacy.load("en_core_web_sm")

# %%
sentences = [review_df.iloc[0]['review'], review_df.iloc[1]['review']]

# %%
sentences

# %%
output = [nlp(x) for x in sentences]

# %%
for token in enumerate(output[0]):
    print(token)

# %%
def build_tagged_documents(documents, tagger):
    for i, document in enumerate(documents):
        processed = tagger(document)
        lemmas = [x.lemma_ for x in processed]
        yield TaggedDocument(lemmas, [i])

# %%
tagged = build_tagged_documents(sentences, nlp)

# %%
tagged

# %%
next(tagged)

# %%
next(tagged)

# %%
next(tagged)

# %%
for x in tagged:
    print(x)

# %%
d2vmodel = Doc2Vec(list(build_tagged_documents(sentences, nlp)))

# %%
len(d2vmodel.dv[0])

# %%
import tqdm

all_reviews_tagged = []
for i, doc in tqdm.tqdm(enumerate(build_tagged_documents(list(review_df[0:3000]['review']), nlp))):
    all_reviews_tagged.append(doc)    
#all_reviews_tagged = list(build_tagged_documents(list(review_df['review']), nlp))

# %%
reviews_d2vmodel = Doc2Vec(all_reviews_tagged)

# %%
short_review_df = review_df[0:3000].copy()

# %%
reviews_d2vmodel.dv[999]

# %%
review_vectors = [reviews_d2vmodel[x] for x in range(3000)]

# %%
short_review_df['vectors'] = review_vectors

# %%
short_review_df

# %%
import pickle

# %%
with open("short_review_df.pkl", "wb") as outputfile:
    pickle.dump(short_review_df, outputfile)

# %%
from review_model import ReviewDataset, ReviewModel, train

# %%
rd = ReviewDataset("short_review_df.pkl")

# %%
model = train("short_review_df.pkl")
# Out:
# 100%|████████████████████████████████████████| 600/600 [00:01<00:00, 393.84it/s]
# tensor(0.7410, grad_fn=<BinaryCrossEntropyBackward0>)
# 100%|████████████████████████████████████████| 600/600 [00:01<00:00, 434.81it/s]
# tensor(0.6894, grad_fn=<BinaryCrossEntropyBackward0>)
# 100%|████████████████████████████████████████| 600/600 [00:01<00:00, 455.21it/s]
# tensor(0.6197, grad_fn=<BinaryCrossEntropyBackward0>)
# 100%|████████████████████████████████████████| 600/600 [00:01<00:00, 415.59it/s]
# tensor(0.6260, grad_fn=<BinaryCrossEntropyBackward0>)
# 100%|████████████████████████████████████████| 600/600 [00:01<00:00, 396.55it/s]
# tensor(0.6833, grad_fn=<BinaryCrossEntropyBackward0>)
# 100%|████████████████████████████████████████| 600/600 [00:01<00:00, 412.49it/s]
# tensor(0.8091, grad_fn=<BinaryCrossEntropyBackward0>)
# 100%|████████████████████████████████████████| 600/600 [00:01<00:00, 419.65it/s]
# tensor(0.7628, grad_fn=<BinaryCrossEntropyBackward0>)
# 100%|████████████████████████████████████████| 600/600 [00:01<00:00, 448.26it/s]
# tensor(0.6979, grad_fn=<BinaryCrossEntropyBackward0>)
# 100%|████████████████████████████████████████| 600/600 [00:01<00:00, 462.42it/s]
# tensor(0.7214, grad_fn=<BinaryCrossEntropyBackward0>)
# 100%|████████████████████████████████████████| 600/600 [00:01<00:00, 349.54it/s]
# tensor(0.7358, grad_fn=<BinaryCrossEntropyBackward0>)

# %%
import torch
torch.stack(list(rd[4:10][0]))

# %%
torch.LongTensor(list(rd[4:10][1]))

# %%
len(rd)

# %%
import torch

rd.review_df['vectors'].apply(lambda x: torch.FloatTensor(x))[4]
