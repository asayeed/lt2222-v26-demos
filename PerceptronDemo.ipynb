# %%
import perceptron

# %%
dir(perceptron)
# Out:
# ['Perceptron',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'np']

# %%
perceptron.Perceptron
# Out:
# perceptron.Perceptron

# %%
p = perceptron.Perceptron()

# %%
1 if True else 0
# Out:
# 1
